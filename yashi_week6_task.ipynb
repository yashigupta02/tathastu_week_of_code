# %% [markdown]
# <a href="https://colab.research.google.com/github/yashigupta02/tathastu_week_of_code/blob/master/yashi_week6_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install minisom

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
from sklearn.preprocessing import MinMaxScaler
from minisom import MiniSom
from pylab import bone, pcolor, colorbar, plot, show
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications (1).csv')
data.head()
# Out:
#    CustomerID  A1     A2     A3  A4  A5  ...  A10  A11  A12  A13   A14  Class
# 0    15776156   1  22.08  11.46   2   4  ...    0    1    2  100  1213      0
# 1    15739548   0  22.67   7.00   2   8  ...    0    0    2  160     1      0
# 2    15662854   0  29.58   1.75   1   4  ...    0    1    2  280     1      0
# 3    15687688   0  21.67  11.50   1   5  ...   11    1    2    0     1      1
# 4    15715750   1  20.17   8.17   2   6  ...   14    0    2   60   159      1
#
# [5 rows x 16 columns]

# %%
data.dtypes
# Out:
# CustomerID      int64
# A1              int64
# A2            float64
# A3            float64
# A4              int64
# A5              int64
# A6              int64
# A7            float64
# A8              int64
# A9              int64
# A10             int64
# A11             int64
# A12             int64
# A13             int64
# A14             int64
# Class           int64
# dtype: object

# %%
data.shape
# Out:
# (690, 16)

# %%
data.describe()
# Out:
#          CustomerID          A1  ...            A14       Class
# count  6.900000e+02  690.000000  ...     690.000000  690.000000
# mean   1.569047e+07    0.678261  ...    1018.385507    0.444928
# std    7.150647e+04    0.467482  ...    5210.102598    0.497318
# min    1.556571e+07    0.000000  ...       1.000000    0.000000
# 25%    1.563169e+07    0.000000  ...       1.000000    0.000000
# 50%    1.569016e+07    1.000000  ...       6.000000    0.000000
# 75%    1.575190e+07    1.000000  ...     396.500000    1.000000
# max    1.581544e+07    1.000000  ...  100001.000000    1.000000
#
# [8 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
sc = MinMaxScaler()
x = sc.fit_transform(x)

# %%
ms = MiniSom(x=10, y=10, input_len=15, sigma=1.0, learning_rate=0.5)

# %%
ms.random_weights_init(x)

# %%
ms.train_random(data=x, num_iteration=100)

# %%
plt.figure(figsize = (20,10))
bone()

# %%
plt.figure(figsize = (20,10))
bone()
pcolor(ms.distance_map().T)
colorbar()

# %%
ms.distance_map().shape
# Out:
# (10, 10)

# %%
plt.figure(figsize = (20,10))
bone()
pcolor(ms.distance_map().T)
colorbar()
markers = ['o', 's']
colors = ['red', 'cyan']
for i,j in enumerate(x):
    wn = ms.winner(j)
    plot(wn[0] + 0.5, wn[1] + 0.5, markers[y[i]], markeredgecolor = colors[y[i]], markerfacecolor = 'None', markersize=15,
         markeredgewidth=3)
show()

# %%
corr = data.corr()
fig = plt.figure(figsize= (15,13))
sns.heatmap(corr, annot=True, fmt='.2g', square=True, vmax=0.5)
plt.show()

# %%
mappings = ms.win_map(x)
mappings.keys()
# Out:
# dict_keys([(0, 5), (6, 3), (0, 4), (7, 1), (9, 5), (8, 1), (9, 2), (1, 8), (8, 0), (1, 3), (1, 0), (9, 0), (6, 7), (3, 9), (3, 2), (2, 7), (1, 1), (6, 0), (3, 5), (7, 4), (9, 9), (8, 6), (6, 9), (1, 4), (0, 2), (8, 8), (0, 6), (4, 0), (6, 8), (7, 9), (4, 8), (9, 6), (4, 2), (5, 7), (8, 5), (9, 3), (3, 0), (3, 4), (4, 4), (6, 5), (3, 6), (2, 9), (6, 4), (9, 7), (2, 3), (8, 7), (2, 6), (5, 5), (3, 1), (3, 7), (4, 9), (6, 6), (1, 7), (2, 5), (8, 2), (8, 9), (4, 1), (7, 7), (0, 9), (2, 8), (4, 5), (9, 4), (1, 6), (7, 5), (5, 1), (1, 9), (4, 7), (4, 6), (0, 7), (6, 1), (0, 1), (9, 1), (5, 8), (7, 8), (5, 9), (9, 8), (5, 2), (7, 6), (3, 8), (5, 6)])

# %%
frauds = mappings[(4,8)]
np.asarray(frauds).shape
# Out:
# (9, 15)

# %%
frauds = sc.inverse_transform(frauds)
np.asarray(frauds).shape
# Out:
# (9, 15)

# %%
df_frauds = pd.DataFrame(frauds)
df_frauds
# Out:
#            0    1      2       3    4     5   ...   9     10   11   12     13     14
# 0  15594305.0  0.0  23.75   0.710  2.0   9.0  ...  1.0   1.0  1.0  2.0  240.0    5.0
# 1  15664793.0  0.0  17.33   9.500  2.0   6.0  ...  1.0  10.0  1.0  2.0    0.0   11.0
# 2  15670029.0  0.0  16.92   0.500  2.0   3.0  ...  1.0   6.0  1.0  2.0  240.0   36.0
# 3  15662189.0  0.0  28.58   3.750  2.0   8.0  ...  1.0   1.0  1.0  2.0   40.0  155.0
# 4  15568469.0  0.0  15.83   7.625  2.0  11.0  ...  1.0   1.0  1.0  2.0    0.0  161.0
# 5  15586479.0  0.0  27.25   0.290  2.0   7.0  ...  1.0   1.0  1.0  2.0  272.0  109.0
# 6  15717700.0  0.0  23.58   0.830  2.0  11.0  ...  1.0   1.0  1.0  2.0  200.0   12.0
# 7  15705379.0  0.0  30.58  10.665  2.0  11.0  ...  1.0  12.0  1.0  2.0  129.0    4.0
# 8  15646535.0  0.0  17.92   0.540  2.0   8.0  ...  1.0   1.0  1.0  2.0   80.0    6.0
#
# [9 rows x 15 columns]

# %% [markdown]
# There are 3 fraudsters in total.
