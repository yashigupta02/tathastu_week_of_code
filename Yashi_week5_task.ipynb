# %% [markdown]
# <a href="https://colab.research.google.com/github/yashigupta02/tathastu_week_of_code/blob/master/Yashi_week5_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17')

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.610315
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.678085
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.818838
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.952841
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.932299

# %%
print(df.dtypes)
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
df.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  2003.000000  2003.000000  ...  2.003000e+03  2003.000000
# mean     31.798525    31.238634  ...  2.384275e+08    29.523361
# std      12.507078    12.308627  ...  1.875556e+08    12.795978
# min      14.271429    13.753571  ...  4.544800e+07    12.152316
# 25%      21.662499    21.228750  ...  1.104316e+08    18.624002
# 50%      28.504999    27.915001  ...  1.747996e+08    26.091917
# 75%      41.484999    40.531250  ...  2.992836e+08    39.260998
# max      70.442497    69.699997  ...  1.506120e+09    69.177261
#
# [8 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2003 entries, 2012-01-03 to 2019-12-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2003 non-null   float64
#  1   Low        2003 non-null   float64
#  2   Open       2003 non-null   float64
#  3   Close      2003 non-null   float64
#  4   Volume     2003 non-null   float64
#  5   Adj Close  2003 non-null   float64
# dtypes: float64(6)
# memory usage: 109.5 KB

# %%
df.plot.scatter(x = 'High', y = 'Volume', c = 'green')

# %%
sns.heatmap(df.corr(), annot=True, cmap="icefire")
plt.show()

# %% [markdown]
# Observations
#
#
# *   Zero null values in the datasheet.

# %%
plt.figure(figsize=(20, 10))
plt.title('Closed Price')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=30)
plt.ylabel('Close Price in Dollars', fontsize=30)
# Out:
# Text(0, 0.5, 'Close Price in Dollars')

# %%
plt.figure(figsize=(20, 10))
plt.title('Opened Price')
plt.plot(df['Open'])
plt.xlabel('Date', fontsize=30)
plt.ylabel('Open Price in Dollars', fontsize=30)
# Out:
# Text(0, 0.5, 'Open Price in Dollars')

# %%
data = df.filter(['Close'])
data2 = data.values
print(data2)
# Out:
# [[14.6867857 ]
#  [14.76571369]
#  [14.92964268]
#  ...
#  [68.78749847]
#  [69.96499634]
#  [70.10250092]]

# %%
training_data_size = math.ceil(len(data2)*.8)
training_data_size
# Out:
# 1603

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data2)
print(scaled_data.shape)
print(scaled_data)
# Out:
# (2003, 1)
# [[0.01316509]
#  [0.01457063]
#  [0.01748985]
#  ...
#  [0.97658263]
#  [0.99755134]
#  [1.        ]]

# %%
train_data = scaled_data[0:training_data_size, :]
print(len(train_data))
x_train, y_train = [], []
for i in range(100, len(train_data)):
    x_train.append(train_data[i-100:i, 0])
    y_train.append(train_data[i,0])
    if i<=100:
       print(x_train)
       print(y_train)
       print()
# Out:
# 1603
# [array([0.01316509, 0.01457063, 0.01748985, 0.02026915, 0.01984303,
#        0.02080338, 0.02036454, 0.01962679, 0.01862191, 0.02173194,
#        0.02453668, 0.02367172, 0.01893355, 0.02345548, 0.01900352,
#        0.03569838, 0.03440732, 0.0360927 , 0.03973694, 0.04194384,
#        0.0417594 , 0.0410789 , 0.04397903, 0.04670744, 0.04979839,
#        0.05479095, 0.0652785 , 0.06543749, 0.07127594, 0.07563885,
#        0.06814049, 0.07102789, 0.07097066, 0.07906688, 0.07791571,
#        0.08004628, 0.08387497, 0.08600558, 0.09214292, 0.09661394,
#        0.09790501, 0.09835659, 0.09071194, 0.08886753, 0.08914103,
#        0.09632778, 0.09835024, 0.10269409, 0.11293358, 0.12659476,
#        0.12403805, 0.1240444 , 0.13392141, 0.13701237, 0.13481179,
#        0.13280207, 0.13070964, 0.13766105, 0.14243103, 0.14442805,
#        0.13949272, 0.13293563, 0.14507041, 0.15186917, 0.14868284,
#        0.15464214, 0.1562639 , 0.15130952, 0.14988489, 0.14770341,
#        0.13654806, 0.12058461, 0.13939096, 0.13852602, 0.12523371,
#        0.11603724, 0.11522315, 0.10796011, 0.13958174, 0.13811897,
#        0.13512978, 0.12303317, 0.1218566 , 0.12430516, 0.12165943,
#        0.111121  , 0.11381126, 0.11298446, 0.11362044, 0.11447267,
#        0.11204956, 0.10664995, 0.10343818, 0.09892898, 0.08877851,
#        0.08894386, 0.10859608, 0.10585498, 0.11449815, 0.11116553])]
# [0.10923844534122418]

# %%
test_data = scaled_data[training_data_size:, :]
print(len(test_data))
x_test, y_test = [], []
for i in range(100, len(test_data)):
    x_test.append(test_data[i-100:i, 0])
    y_test.append(train_data[i,0])
    if i<=100:
       print(x_test)
       print(y_test)
# Out:
# 400
# [array([0.5840976 , 0.58107023, 0.58694685, 0.58485443, 0.59019677,
#        0.58926183, 0.59117621, 0.58814884, 0.58636808, 0.58356332,
#        0.59856648, 0.60564509, 0.61223397, 0.61521678, 0.61290181,
#        0.60506631, 0.60297388, 0.60764846, 0.60061435, 0.60105957,
#        0.59233369, 0.59188854, 0.57831003, 0.58191611, 0.5772861 ,
#        0.574882  , 0.5626391 , 0.57270052, 0.57149854, 0.57746415,
#        0.57572789, 0.58494342, 0.57043004, 0.57701893, 0.58846051,
#        0.60008013, 0.5990562 , 0.58805984, 0.6020835 , 0.6034191 ,
#        0.60154929, 0.60395332, 0.59927874, 0.6058677 , 0.60390882,
#        0.60466565, 0.61085388, 0.61895648, 0.61624078, 0.60186089,
#        0.59709732, 0.59878902, 0.64869556, 0.67491762, 0.67758883,
#        0.68239696, 0.67367108, 0.67429435, 0.68155107, 0.6755409 ,
#        0.68150651, 0.68542426, 0.68760575, 0.7013178 , 0.72028314,
#        0.710845  , 0.70897512, 0.70901968, 0.71097855, 0.71396136,
#        0.72188585, 0.72972128, 0.74432371, 0.75345025, 0.76502538,
#        0.7682753 , 0.76164185, 0.744858  , 0.73684445, 0.72362211,
#        0.74819697, 0.73582052, 0.75959398, 0.74815241, 0.72161874,
#        0.72322145, 0.72380016, 0.73119044, 0.72063931, 0.7345739 ,
#        0.74080669, 0.7329267 , 0.75309409, 0.75661118, 0.76337811,
#        0.7723711 , 0.78479211, 0.76662809, 0.75015578, 0.7478408 ])]
# [0.10923844534122418]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1], 1))
print(x_train.shape, y_train.shape)
# Out:
# (1503, 100, 1) (1503,)

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1], 1))
print(x_test.shape, y_test.shape)
# Out:
# (300, 100, 1) (300,)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(25))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 25)                7600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 38,226
# Trainable params: 38,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size= 64, epochs = 100, verbose=1)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 11s 227ms/step - loss: 0.0161 - val_loss: 0.2411
# Epoch 2/100
# 24/24 [==============================] - 4s 170ms/step - loss: 0.0011 - val_loss: 0.3801
# Epoch 3/100
# 24/24 [==============================] - 4s 179ms/step - loss: 5.2710e-04 - val_loss: 0.3276
# Epoch 4/100
# 24/24 [==============================] - 4s 164ms/step - loss: 4.5800e-04 - val_loss: 0.3256
# Epoch 5/100
# 24/24 [==============================] - 4s 174ms/step - loss: 4.4768e-04 - val_loss: 0.3282
# Epoch 6/100
# 24/24 [==============================] - 4s 167ms/step - loss: 4.5314e-04 - val_loss: 0.3233
# Epoch 7/100
# 24/24 [==============================] - 4s 178ms/step - loss: 4.4835e-04 - val_loss: 0.3121
# Epoch 8/100
# 24/24 [==============================] - 4s 174ms/step - loss: 4.2393e-04 - val_loss: 0.3271
# Epoch 9/100
# 24/24 [==============================] - 4s 168ms/step - loss: 4.2677e-04 - val_loss: 0.3213
# Epoch 10/100
# 24/24 [==============================] - 4s 180ms/step - loss: 4.1268e-04 - val_loss: 0.3228
# Epoch 11/100
# 24/24 [==============================] - 4s 172ms/step - loss: 4.0861e-04 - val_loss: 0.3415
# Epoch 12/100
# 24/24 [==============================] - 4s 175ms/step - loss: 3.9969e-04 - val_loss: 0.3402
# Epoch 13/100
# 24/24 [==============================] - 4s 178ms/step - loss: 3.9135e-04 - val_loss: 0.3277
# Epoch 14/100
# 24/24 [==============================] - 4s 163ms/step - loss: 3.7742e-04 - val_loss: 0.3255
# Epoch 15/100
# 24/24 [==============================] - 4s 176ms/step - loss: 3.7368e-04 - val_loss: 0.3309
# Epoch 16/100
# 24/24 [==============================] - 4s 179ms/step - loss: 3.6276e-04 - val_loss: 0.3275
# Epoch 17/100
# 24/24 [==============================] - 4s 181ms/step - loss: 3.5297e-04 - val_loss: 0.3425
# Epoch 18/100
# 24/24 [==============================] - 4s 181ms/step - loss: 3.5818e-04 - val_loss: 0.3363
# Epoch 19/100
# 24/24 [==============================] - 4s 177ms/step - loss: 3.4163e-04 - val_loss: 0.3298
# Epoch 20/100
# 24/24 [==============================] - 4s 163ms/step - loss: 3.5188e-04 - val_loss: 0.3470
# Epoch 21/100
# 24/24 [==============================] - 4s 169ms/step - loss: 3.2692e-04 - val_loss: 0.3191
# Epoch 22/100
# 24/24 [==============================] - 5s 189ms/step - loss: 3.0951e-04 - val_loss: 0.3360
# Epoch 23/100
# 24/24 [==============================] - 4s 177ms/step - loss: 3.0782e-04 - val_loss: 0.3685
# Epoch 24/100
# 24/24 [==============================] - 4s 172ms/step - loss: 3.0111e-04 - val_loss: 0.3527
# Epoch 25/100
# 24/24 [==============================] - 4s 172ms/step - loss: 2.9024e-04 - val_loss: 0.3440
# Epoch 26/100
# 24/24 [==============================] - 4s 168ms/step - loss: 2.9774e-04 - val_loss: 0.3115
# Epoch 27/100
# 24/24 [==============================] - 4s 179ms/step - loss: 3.4663e-04 - val_loss: 0.3451
# Epoch 28/100
# 24/24 [==============================] - 4s 180ms/step - loss: 2.7563e-04 - val_loss: 0.3432
# Epoch 29/100
# 24/24 [==============================] - 4s 180ms/step - loss: 2.6594e-04 - val_loss: 0.3211
# Epoch 30/100
# 24/24 [==============================] - 4s 173ms/step - loss: 3.2185e-04 - val_loss: 0.3462
# Epoch 31/100
# 24/24 [==============================] - 4s 173ms/step - loss: 2.5752e-04 - val_loss: 0.3281
# Epoch 32/100
# 24/24 [==============================] - 4s 169ms/step - loss: 2.9230e-04 - val_loss: 0.3301
# Epoch 33/100
# 24/24 [==============================] - 4s 184ms/step - loss: 2.4008e-04 - val_loss: 0.3497
# Epoch 34/100
# 24/24 [==============================] - 4s 180ms/step - loss: 2.3860e-04 - val_loss: 0.3549
# Epoch 35/100
# 24/24 [==============================] - 4s 168ms/step - loss: 2.2963e-04 - val_loss: 0.3437
# Epoch 36/100
# 24/24 [==============================] - 4s 168ms/step - loss: 2.3267e-04 - val_loss: 0.3241
# Epoch 37/100
# 24/24 [==============================] - 4s 181ms/step - loss: 2.3255e-04 - val_loss: 0.3387
# Epoch 38/100
# 24/24 [==============================] - 4s 182ms/step - loss: 2.1666e-04 - val_loss: 0.3424
# Epoch 39/100
# 24/24 [==============================] - 4s 182ms/step - loss: 2.3013e-04 - val_loss: 0.3196
# Epoch 40/100
# 24/24 [==============================] - 4s 182ms/step - loss: 2.1907e-04 - val_loss: 0.3340
# Epoch 41/100
# 24/24 [==============================] - 4s 182ms/step - loss: 1.9783e-04 - val_loss: 0.3372
# Epoch 42/100
# 24/24 [==============================] - 4s 179ms/step - loss: 1.9352e-04 - val_loss: 0.3121
# Epoch 43/100
# 24/24 [==============================] - 4s 182ms/step - loss: 2.5120e-04 - val_loss: 0.3361
# Epoch 44/100
# 24/24 [==============================] - 4s 179ms/step - loss: 2.1278e-04 - val_loss: 0.3225
# Epoch 45/100
# 24/24 [==============================] - 4s 184ms/step - loss: 1.9221e-04 - val_loss: 0.3460
# Epoch 46/100
# 24/24 [==============================] - 4s 180ms/step - loss: 1.8300e-04 - val_loss: 0.3524
# Epoch 47/100
# 24/24 [==============================] - 4s 174ms/step - loss: 1.9857e-04 - val_loss: 0.3116
# Epoch 48/100
# 24/24 [==============================] - 4s 179ms/step - loss: 1.9106e-04 - val_loss: 0.3291
# Epoch 49/100
# 24/24 [==============================] - 4s 177ms/step - loss: 1.6624e-04 - val_loss: 0.3378
# Epoch 50/100
# 24/24 [==============================] - 4s 174ms/step - loss: 1.6732e-04 - val_loss: 0.3354
# Epoch 51/100
# 24/24 [==============================] - 4s 178ms/step - loss: 1.6067e-04 - val_loss: 0.3267
# Epoch 52/100
# 24/24 [==============================] - 4s 177ms/step - loss: 1.6090e-04 - val_loss: 0.3349
# Epoch 53/100
# 24/24 [==============================] - 4s 177ms/step - loss: 1.5125e-04 - val_loss: 0.3356
# Epoch 54/100
# 24/24 [==============================] - 4s 179ms/step - loss: 1.4856e-04 - val_loss: 0.3281
# Epoch 55/100
# 24/24 [==============================] - 4s 178ms/step - loss: 1.6765e-04 - val_loss: 0.3247
# Epoch 56/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.5273e-04 - val_loss: 0.3482
# Epoch 57/100
# 24/24 [==============================] - 4s 168ms/step - loss: 1.5914e-04 - val_loss: 0.3347
# Epoch 58/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.3968e-04 - val_loss: 0.3306
# Epoch 59/100
# 24/24 [==============================] - 4s 178ms/step - loss: 1.3560e-04 - val_loss: 0.3506
# Epoch 60/100
# 24/24 [==============================] - 4s 167ms/step - loss: 1.6134e-04 - val_loss: 0.3461
# Epoch 61/100
# 24/24 [==============================] - 4s 165ms/step - loss: 1.3598e-04 - val_loss: 0.3421
# Epoch 62/100
# 24/24 [==============================] - 4s 167ms/step - loss: 1.3805e-04 - val_loss: 0.3190
# Epoch 63/100
# 24/24 [==============================] - 4s 164ms/step - loss: 1.3873e-04 - val_loss: 0.3247
# Epoch 64/100
# 24/24 [==============================] - 4s 176ms/step - loss: 1.3043e-04 - val_loss: 0.3318
# Epoch 65/100
# 24/24 [==============================] - 4s 180ms/step - loss: 1.2715e-04 - val_loss: 0.3394
# Epoch 66/100
# 24/24 [==============================] - 4s 171ms/step - loss: 1.3332e-04 - val_loss: 0.3478
# Epoch 67/100
# 24/24 [==============================] - 4s 178ms/step - loss: 1.3889e-04 - val_loss: 0.3441
# Epoch 68/100
# 24/24 [==============================] - 4s 179ms/step - loss: 1.1874e-04 - val_loss: 0.3310
# Epoch 69/100
# 24/24 [==============================] - 4s 172ms/step - loss: 1.3125e-04 - val_loss: 0.3437
# Epoch 70/100
# 24/24 [==============================] - 5s 189ms/step - loss: 1.2266e-04 - val_loss: 0.3449
# Epoch 71/100
# 24/24 [==============================] - 4s 187ms/step - loss: 1.1602e-04 - val_loss: 0.3456
# Epoch 72/100
# 24/24 [==============================] - 4s 179ms/step - loss: 1.3145e-04 - val_loss: 0.3564
# Epoch 73/100
# 24/24 [==============================] - 4s 171ms/step - loss: 1.4545e-04 - val_loss: 0.3459
# Epoch 74/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.2626e-04 - val_loss: 0.3371
# Epoch 75/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.1711e-04 - val_loss: 0.3326
# Epoch 76/100
# 24/24 [==============================] - 4s 166ms/step - loss: 1.0801e-04 - val_loss: 0.3420
# Epoch 77/100
# 24/24 [==============================] - 4s 169ms/step - loss: 1.3184e-04 - val_loss: 0.3444
# Epoch 78/100
# 24/24 [==============================] - 4s 184ms/step - loss: 1.1928e-04 - val_loss: 0.3310
# Epoch 79/100
# 24/24 [==============================] - 5s 189ms/step - loss: 1.1262e-04 - val_loss: 0.3356
# Epoch 80/100
# 24/24 [==============================] - 4s 175ms/step - loss: 1.1071e-04 - val_loss: 0.3371
# Epoch 81/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0609e-04 - val_loss: 0.3321
# Epoch 82/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0371e-04 - val_loss: 0.3421
# Epoch 83/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.1242e-04 - val_loss: 0.3238
# Epoch 84/100
# 24/24 [==============================] - 5s 214ms/step - loss: 1.1234e-04 - val_loss: 0.3331
# Epoch 85/100
# 24/24 [==============================] - 4s 180ms/step - loss: 1.1044e-04 - val_loss: 0.3248
# Epoch 86/100
# 24/24 [==============================] - 4s 185ms/step - loss: 1.0484e-04 - val_loss: 0.3406
# Epoch 87/100
# 24/24 [==============================] - 5s 212ms/step - loss: 1.0844e-04 - val_loss: 0.3257
# Epoch 88/100
# 24/24 [==============================] - 5s 217ms/step - loss: 1.2463e-04 - val_loss: 0.3291
# Epoch 89/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.2384e-04 - val_loss: 0.3260
# Epoch 90/100
# 24/24 [==============================] - 5s 209ms/step - loss: 1.0187e-04 - val_loss: 0.3320
# Epoch 91/100
# 24/24 [==============================] - 5s 199ms/step - loss: 1.0270e-04 - val_loss: 0.3417
# Epoch 92/100
# 24/24 [==============================] - 5s 200ms/step - loss: 9.4816e-05 - val_loss: 0.3397
# Epoch 93/100
# 24/24 [==============================] - 5s 205ms/step - loss: 1.1227e-04 - val_loss: 0.3313
# Epoch 94/100
# 24/24 [==============================] - 5s 198ms/step - loss: 1.0653e-04 - val_loss: 0.3307
# Epoch 95/100
# 24/24 [==============================] - 5s 211ms/step - loss: 1.0405e-04 - val_loss: 0.3431
# Epoch 96/100
# 24/24 [==============================] - 5s 209ms/step - loss: 9.6807e-05 - val_loss: 0.3350
# Epoch 97/100
# 24/24 [==============================] - 5s 212ms/step - loss: 9.6527e-05 - val_loss: 0.3311
# Epoch 98/100
# 24/24 [==============================] - 5s 213ms/step - loss: 9.5544e-05 - val_loss: 0.3359
# Epoch 99/100
# 24/24 [==============================] - 5s 209ms/step - loss: 8.6409e-05 - val_loss: 0.3364
# Epoch 100/100
# 24/24 [==============================] - 5s 195ms/step - loss: 9.2622e-05 - val_loss: 0.3456

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

# %%
train_pred = scaler.inverse_transform(train_pred)
test_pred = scaler.inverse_transform(test_pred)
print(train_pred.shape, test_pred.shape)
# Out:
# (1503, 1) (300, 1)

# %%
math.sqrt(mean_squared_error(y_train, train_pred))
# Out:
# 28.44673596965661

# %%
math.sqrt(mean_squared_error(y_test, test_pred))
# Out:
# 50.74204573964431

# %%
train_pred_plot = np.empty_like(data2)
train_pred_plot[:, :] = np.nan
train_pred_plot[100:len(train_pred)+100, :1] = train_pred
test_pred_plot = np.empty_like(data2)
test_pred_plot[:] = np.nan
test_pred_plot[len(train_pred)+(100*2):len(data2), :] = test_pred
plt.figure(figsize=(19,9))
plt.title('RNN model LSTM')
plt.ylabel('Close Price in Dollars', fontsize=25)
plt.plot(data2)
plt.plot(train_pred_plot)
plt.plot(test_pred_plot)
plt.legend(['Data', 'Train', 'Predictions'], loc='upper left')
plt.show()

# %% [markdown]
# Websites for reference
#
#
# 1.   Stack Over Flow
# 2.   Geek for Geeks
